# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify duplicate values in the dataset.
#
# -   Remove duplicate values from the dataset.
#
# -   Identify missing values in the dataset.
#
# -   Impute the missing values in the dataset.
#
# -   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           4                     I am a developer by profession       No
# 1           9                     I am a developer by profession      Yes
# 2          13                     I am a developer by profession      Yes
# 3          16                     I am a developer by profession      Yes
# 4          17                     I am a developer by profession      Yes
# 5          19                     I am a developer by profession      Yes
# 6          20  I am not primarily a developer, but I write co...       No
# 7          22                     I am a developer by profession      Yes
# 8          23                     I am a developer by profession      Yes
# 9          24                     I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# ...

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
#  Find how many duplicate rows exist in the dataframe.

# %%
# your code goes here
df.duplicated().sum()
# Out:
# 154

# %% [markdown]
# How many duplicate values are there in the column "Respondent"?

# %%
df.duplicated(subset=['Respondent']).sum()
# Out:
# 154

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
# your code goes here
df.drop_duplicates(inplace=True)

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
# your code goes here
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
# your code goes here
missing_data = df.isnull()
missing_data.head(20)
# Out:
#     Respondent  MainBranch  Hobbyist  OpenSourcer  OpenSource  Employment  \
# 0        False       False     False        False       False       False
# 1        False       False     False        False       False       False
# 2        False       False     False        False       False       False
# 3        False       False     False        False       False       False
# 4        False       False     False        False       False       False
# 5        False       False     False        False       False       False
# 6        False       False     False        False       False       False
# 7        False       False     False        False       False       False
# 8        False       False     False        False       False       False
# 9        False       False     False        False       False       False
# 10       False       False     False        False       False       False
# 11       False       False     False        False       False       False
# ...

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# Respondent
# False    11398
# Name: Respondent, dtype: int64
#
# MainBranch
# False    11398
# Name: MainBranch, dtype: int64
#
# Hobbyist
# False    11398
# Name: Hobbyist, dtype: int64
#
# OpenSourcer
# False    11398
# Name: OpenSourcer, dtype: int64
#
# OpenSource
# False    11317
# True        81
# Name: OpenSource, dtype: int64
#
# Employment
# False    11398
# Name: Employment, dtype: int64
#
# Country
# False    11398
# Name: Country, dtype: int64
#
# Student
# False    11347
# True        51
# Name: Student, dtype: int64
#
# EdLevel
# False    11286
# True       112
# Name: EdLevel, dtype: int64
#
# UndergradMajor
# False    10661
# True       737
# Name: UndergradMajor, dtype: int64
#
# EduOther
# False    11234
# True       164
# Name: EduOther, dtype: int64
#
# OrgSize
# False    11302
# True        96
# Name: OrgSize, dtype: int64
#
# DevType
# False    11333
# True        65
# Name: DevType, dtype: int64
#
# YearsCode
# False    11389
# True         9
# ...

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
# your code goes here
df['WorkLoc'].isnull().sum()
# Out:
# 32

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
# your code goes here
df['WorkLoc'].value_counts()
# Out:
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
# make a note of the majority value here, for future reference
frequent = df['WorkLoc'].value_counts().idxmax()
frequent
# Out:
# 'Office'

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
# your code goes here
df['WorkLoc'].fillna('Office', inplace=True)

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
# your code goes here
df['WorkLoc'].isnull().sum()
# Out:
# 0

# %% [markdown]
# What is the majority category under the column "Employment"

# %%
df['Employment'].value_counts()
# Out:
# Employed full-time    10968
# Employed part-time      430
# Name: Employment, dtype: int64

# %% [markdown]
# Under the column " UndergradMajor", which category has the minimum number of rows

# %%
minimum_row = df['UndergradMajor'].value_counts().idxmin()
minimum_row
# Out:
# 'A health science (ex. nursing, pharmacy, radiology)'

# %% [markdown]
# The column ‘ConvertedComp’ contains the annual compensation of the survey respondents. What is the best approach to impute the missing values in this column

# %%
# find the total missing value for the "ConvertedComp" column
missing_values = df['ConvertedComp'].isnull().sum()
print(missing_values)
# Out:
# 816

# %%
# Calculate the median value for the "ConvertedComp" column
avg_ConvertedComp = df['ConvertedComp'].astype('float').median(axis=0)
print("Average ConvertedComp:", avg_ConvertedComp)
# Out:
# Average ConvertedComp: 57745.0

# %%
# Replace "NaN" with the median value in the "ConvertedComp" column
df_ConvertedComp = df['ConvertedComp'].replace(np.nan, avg_ConvertedComp, inplace=True)
df_ConvertedComp

# %%
# check the total missing value for the "ConvertedComp" column
missing_values = df['ConvertedComp'].isnull().sum()
missing_values
# Out:
# 0

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
# your code goes here
df['CompFreq'].value_counts()
# Out:
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: CompFreq, dtype: int64

# %% [markdown]
# How many unique values are there in the "CompFreq" column

# %%
df['CompFreq'].unique()
# Out:
# array(['Yearly', 'Monthly', 'Weekly', nan], dtype=object)

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
# your code goes here

AnnualComp = []

def nac():
    
    for ComFreq, CompTotal in zip(df['CompFreq'], df['CompTotal']):
        if ComFreq == 'Monthly':
            AnnualComp.append(CompTotal*12)
        elif ComFreq == 'Weekly':
            AnnualComp.append(CompTotal*52)
        else:
            AnnualComp.append(CompTotal)
            
nac()

df['NormalizedAnnualCompensation'] = AnnualComp
df.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %% [markdown]
# What is the median "NormalizedAnnualCompensation"

# %%
avg_AnnualCompensation = df['NormalizedAnnualCompensation'].astype('float').median(axis=0)
print("Average AnnualCompensation:", avg_AnnualCompensation)
# Out:
# Average AnnualCompensation: 100000.0

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
